# %%
import numpy as np
import pandas as pd
import torch
from tqdm import tqdm
import time
import os
import csv
import sqlite3
import matplotlib.pyplot  as plt
import random
from collections import defaultdict
import torch

# %%
sharing = pd.read_pickle("/home/dsi/avitalab/savesharing.pickle")

# %%
sharing = sharing[0]
sharing = [0] + sharing

# %%
xaxis = np.arange(1, len(sharing)+1)

# %%
plt.xlabel("number of samples")
plt.ylabel("number of sequences")
plt.legend()
plt.plot(xaxis, sharing)
plt.show()
# Out:
# No handles with labels found to put in legend.
